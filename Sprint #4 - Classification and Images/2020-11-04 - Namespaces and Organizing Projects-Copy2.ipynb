# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import classy
# Out:
# Version:  0.0.28

# %%
import classy as cl

# %%
import numpy as np
import pandas as pd

# %%
images=cl.image.load_images('Nim Images/')
# Out:
# [blank]: 5 files found
# [piece]: 10 files found

# %%
data=classy.image.images_to_vectors(images)
# Out:
# 15 vectors of length 18720
# Feature names: 'p0', 'p1', 'p2', 'p3', 'p4'  , ... ,  'p18715', 'p18716', 'p18717', 'p18718', 'p18719'  (18720 features)
# Target values given.
# Target names: 'blank', 'piece'
# Mean:  [254.93333333 254.93333333 254.93333333 ... 252.06666667 252.06666667
#  252.06666667]
# Median:  [255. 255. 255. ... 255. 255. 255.]
# Stddev:  [ 0.24944383  0.24944383  0.24944383 ... 10.45285713 10.45285713
#  10.45285713]

# %%
data_train,data_test=classy.split(data)
# Out:
# Original vector shape:  (15, 18720)
# Train vector shape:  (11, 18720)
# Test vector shape:  (4, 18720)

# %%
import mynim
# Out:
# Version:  0.2.23

# %%
mynim.initial_state()
# Out:
# 20

# %%
plot(rand(1000))

# %%
mynim.plot(rand(1000))
# Out:
# Here I am!

# %%
plot??
# Out:
# Signature: plot(*args, scalex=True, scaley=True, data=None, **kwargs)
# Source:
# @_copy_docstring_and_deprecators(Axes.plot)
# def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
#     return gca().plot(
#         *args, scalex=scalex, scaley=scaley,
#         **({"data": data} if data is not None else {}), **kwargs)
# File:      ~/opt/anaconda3/envs/py3/lib/python3.7/site-packages/matplotlib/pyplot.py
# Type:      function

# %%
mynim.__file__
# Out:
# '/Users/bblais/Documents/Git/AI-and-Robotics-Fall-2020-Class-Notebooks/Sprint #4 - Classification and Images/mynim.py'

# %%
mynim.plot??
# Out:
# Signature: mynim.plot(something)
# Source:
# def plot(something):
#     print("Here I am!")
# File:      ~/Documents/Git/AI-and-Robotics-Fall-2020-Class-Notebooks/Sprint #4 - Classification and Images/mynim.py
# Type:      function

# %%
plot1=plot
plot2=mynim.plot

# %%
plot1(rand(100))

# %%
from mynim import plot as plot3

# %%
plot3('asdasd')
# Out:
# Here I am!

# %%
from mynim import initial_state
