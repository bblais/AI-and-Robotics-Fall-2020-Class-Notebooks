# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x=rand(1000)
v=randn(1000)

# %%
plot(x)

# %%
plot(x)
plot(v)

# %%
subplot(2,1,1)
plot(x)

subplot(2,1,2)
plot(v)

# %%
for i in range(4):
    subplot(4,1,i+1)
    
    imshow(rand(100,100))

# %%
for i in range(4):
    subplot(2,2,i+1)
    
    imshow(rand(100,100))

# %%
for i in range(4):
    subplot(1,4,i+1)
    
    imshow(rand(100,100))

# %%
subplot(2,1,1)
plot(x)


subplot(2,2,3)
imshow(rand(100,100))

subplot(2,2,4)
imshow(rand(100,100))
