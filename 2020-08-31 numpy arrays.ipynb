# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
r=rand(10)

# %%
r
# Out:
# array([0.65069319, 0.5432195 , 0.93183516, 0.40685805, 0.93921621,
#        0.47859385, 0.44083124, 0.79485373, 0.83511035, 0.99595145])

# %%
r=rand(10)

# %%
r
# Out:
# array([0.65767487, 0.3810437 , 0.13591195, 0.06285291, 0.19842458,
#        0.34336893, 0.12257423, 0.877972  , 0.77026012, 0.48962289])

# %%
type(r)
# Out:
# numpy.ndarray

# %%
r[1]
# Out:
# 0.3810436984632368

# %%
rand(3)
# Out:
# array([0.85646484, 0.43249643, 0.16351658])

# %%
rand(5)
# Out:
# array([0.54918251, 0.24303908, 0.09520055, 0.7677717 , 0.23588146])

# %%
plot(rand(100))

# %%
plot(rand(1000))
