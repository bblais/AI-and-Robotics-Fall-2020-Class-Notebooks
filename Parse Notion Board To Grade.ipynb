# %%
import pandas as pd
from numpy import nan,mean

# %%
names={}

names['Sprint #1']=list(pd.read_csv('data/Original Sprint #1 Scrum Kanban- Programming and Games.csv')['Name'])
names['Sprint #2']=list(pd.read_csv('data/Original Sprint #2 Scrum Kanban - Learning and Simulation.csv')['Name'])
names
# Out:
# {'Sprint #1': ['Set Up Computer for Class',
#   'Make Your Own Copy of the Scrum Board',
#   'Learn About the Turing Test and Thought',
#   'recipe for drawing squares in turtle',
#   'function for drawing a house',
#   'function for setting size and/or shape',
#   'Using if-then structure to deal with alternating patterns',
#   'loops for doing repetitive tasks',
#   'nested loops (i.e. loops within loops)',
#   'Learn about Generic Game Outlines',
#   'Learn About Agents',
#   'Download the Game Library',
#   'Implement Small Board Game',
#   'Present the Logic of a Small Board Game',
#   'Learn About Search',
#   'Minimax SRPS',
#   'Minimax SRPS-2',
#   'Apply Minimax to Endgame',
#   "Solve the 3x3, 4x4, ... , 8x8 Queen's Problem",
#   "Write a *recipe* (on paper, or typed out) for the computer to solve the 100x100 Queen's problem",
#   'Find a solution to the sentence problem where the blanks are filled in with digits (which will upset the counts). Note that a “10” has a “1” and a “0”: This sentence contains ___ 0’s, ___ 1’s,\xa0___ 2’s,\xa0___ 3’s,\xa0___ 4’s,\xa0___ 5’s,\xa0___ 6’s,\xa0___ 7’s, ___ 8’s, and\xa0___ 9’s.'],
#  'Sprint #2': ['Make sure that minimax works for your game',
#   'Determine how minimax scales with search size',
#   'Learn Simple Skittles Reinforcement Learning',
#   'Learn Q-Learning',
#   'Implement Skittles Agent for your game',
#   'Implement Q-learning for your game',
#   'Set Up Robot Simulator',
#   'Make python functions for simple motor tasks (e.g. moving forward a given distance, turning right 90 degrees, etc...)',
#   'Learn to have the robot take pictures and convey the images to your notebook',
#   'Look through all of the example robot scripts and summarize what they do',
#   'Make your robot do something interesting']}

# %% [markdown]
# 1. Upper right corner of your notebook (the three dots), Export...
#
# <img src="images/Screen Shot 2020-09-21 at 08.59.24.png" width=300>
#
# 2. Choose Markdown & CSV, and it will save as a .zip file
#
# <img src="images/Screen Shot 2020-09-20 at 15.13.33.png" width=500>

# %%
# replace these file names with the ones you downloaded for each sprint

data1=pd.read_csv('/Users/bblais/Downloads/Sprint 1 Export-486501b0-1668-4c6f-b04b-7bb8e87ec9f5.zip')
data2=pd.read_csv('/Users/bblais/Downloads/Sprint 2 Export-e24a0a56-f9ea-46c4-b03d-66d72e0b9c1d.zip')
display(data1)
display(data2)

feedback={}
for row in data1.iterrows():
    
    feedback[row[1]['Name']]=row[1]['Feedback Code']
for row in data2.iterrows():
    feedback[row[1]['Name']]=row[1]['Feedback Code']
# Out:
#                                                  Name Feedback Code  \
# 0                           Set Up Computer for Class            c1
# 1               Make Your Own Copy of the Scrum Board           NaN
# 2             Learn About the Turing Test and Thought            cc
# 3                recipe for drawing squares in turtle            00
# 4                        function for drawing a house            c1
# 5              function for setting size and/or shape            cc
# 6   Using if-then structure to deal with alternati...            c1
# 7                    loops for doing repetitive tasks            c1
# 8              nested loops (i.e. loops within loops)            c2
# 9                   Learn about Generic Game Outlines            cc
# 10                                 Learn About Agents            cc
# 11                          Download the Game Library            cc
# 12                         Implement Small Board Game            cc
# 13            Present the Logic of a Small Board Game            cc
# 14                                 Learn About Search            cc
# 15                                       Minimax SRPS        c2, p1
# 16                                     Minimax SRPS-2            c2
# 17                           Apply Minimax to Endgame            00
# 18      Solve the 3x3, 4x4, ... , 8x8 Queen's Problem            cc
# 19  Write a *recipe* (on paper, or typed out) for ...            cc
# 20  Find a solution to the sentence problem where ...            c0
#
#     Objectives     Sprint  Status
# 0          NaN  Sprint #1     NaN
# 1          NaN  Sprint #1     NaN
# 2          NaN  Sprint #1     NaN
# 3          NaN  Sprint #1     NaN
# 4          NaN  Sprint #1     NaN
# 5          NaN  Sprint #1     NaN
# 6          NaN  Sprint #1     NaN
# 7          NaN  Sprint #1     NaN
# 8          NaN  Sprint #1     NaN
# 9          NaN  Sprint #1     NaN
# 10         NaN  Sprint #1     NaN
# 11         NaN  Sprint #1     NaN
# 12         NaN  Sprint #1     NaN
# 13         NaN  Sprint #1     NaN
# 14         NaN  Sprint #1     NaN
# 15         NaN  Sprint #1     NaN
# 16         NaN  Sprint #1     NaN
# 17         NaN  Sprint #1     NaN
# 18         NaN  Sprint #1     NaN
# 19         NaN  Sprint #1     NaN
# 20         NaN  Sprint #1     NaN
#                                                  Name Feedback Code  \
# 0          Make sure that minimax works for your game            c1
# 1       Determine how minimax scales with search size           NaN
# 2        Learn Simple Skittles Reinforcement Learning            c2
# 3                                    Learn Q-Learning           NaN
# 4              Implement Skittles Agent for your game           NaN
# 5                  Implement Q-learning for your game           NaN
# 6                              Set Up Robot Simulator           NaN
# 7   Make python functions for simple motor tasks (...           NaN
# 8   Learn to have the robot take pictures and conv...           NaN
# 9   Look through all of the example robot scripts ...           NaN
# 10           Make your robot do something interesting           NaN
#
#        Sprint  Status
# 0   Sprint #2     NaN
# 1   Sprint #2     NaN
# 2   Sprint #2     NaN
# 3   Sprint #2     NaN
# 4   Sprint #2     NaN
# 5   Sprint #2     NaN
# 6   Sprint #2     NaN
# 7   Sprint #2     NaN
# 8   Sprint #2     NaN
# 9   Sprint #2     NaN
# 10  Sprint #2     NaN

# %%
feedback
# Out:
# {'Set Up Computer for Class': 'c1',
#  'Make Your Own Copy of the Scrum Board': nan,
#  'Learn About the Turing Test and Thought': 'cc',
#  'recipe for drawing squares in turtle': '00',
#  'function for drawing a house': 'c1',
#  'function for setting size and/or shape': 'cc',
#  'Using if-then structure to deal with alternating patterns': 'c1',
#  'loops for doing repetitive tasks': 'c1',
#  'nested loops (i.e. loops within loops)': 'c2',
#  'Learn about Generic Game Outlines': 'cc',
#  'Learn About Agents': 'cc',
#  'Download the Game Library': 'cc',
#  'Implement Small Board Game': 'cc',
#  'Present the Logic of a Small Board Game': 'cc',
#  'Learn About Search': 'cc',
#  'Minimax SRPS': 'c2, p1',
#  'Minimax SRPS-2': 'c2',
#  'Apply Minimax to Endgame': '00',
#  "Solve the 3x3, 4x4, ... , 8x8 Queen's Problem": 'cc',
#  "Write a *recipe* (on paper, or typed out) for the computer to solve the 100x100 Queen's problem": 'cc',
#  'Find a solution to the sentence problem where the blanks are filled in with digits (which will upset the counts). Note that a “10” has a “1” and a “0”: This sentence contains ___ 0’s, ___ 1’s,\xa0___ 2’s,\xa0___ 3’s,\xa0___ 4’s,\xa0___ 5’s,\xa0___ 6’s,\xa0___ 7’s, ___ 8’s, and\xa0___ 9’s.': 'c0',
#  'Make sure that minimax works for your game': 'c1',
#  'Determine how minimax scales with search size': nan,
#  'Learn Simple Skittles Reinforcement Learning': 'c2',
#  'Learn Q-Learning': nan,
#  'Implement Skittles Agent for your game': nan,
#  'Implement Q-learning for your game': nan,
#  'Set Up Robot Simulator': nan,
#  'Make python functions for simple motor tasks (e.g. moving forward a given distance, turning right 90 degrees, etc...)': nan,
#  'Learn to have the robot take pictures and convey the images to your notebook': nan,
#  'Look through all of the example robot scripts and summarize what they do': nan,
#  'Make your robot do something interesting': nan}

# %%
student_item_names=feedback.keys()
total=0
count=0

scores={'cc':100,'c2':90,'c1':60,'c0':30,'00':0,'nan':0,
       'p2':90,'p1':60,'p0':30}

for sprint in names:
    sprint_count=0
    sprint_total=0
    
    for name in names[sprint]:


        fb=None
        if name in student_item_names:
            fb=feedback[name]
        else:
            for sn in student_item_names:
                if sn[:20]==name[:20]:  # match beginning
                    fb=feedback[sn]
                    break


        if not fb:
            raise ValueError(name)

        codes=str(fb).split(",")

        score=mean([scores[_.strip()] for _ in codes])
        print(name,"\t",fb,"\t",score)
        total+=score
        count+=1
        sprint_total+=score
        sprint_count+=1
        
    print()
    print("%s Average: %.2f" % (sprint,sprint_total/sprint_count))
    print()
    
total=total/count
print()
print("Average: ",total)
# Out:
# Set Up Computer for Class 	 c1 	 60.0
# Make Your Own Copy of the Scrum Board 	 nan 	 0.0
# Learn About the Turing Test and Thought 	 cc 	 100.0
# recipe for drawing squares in turtle 	 00 	 0.0
# function for drawing a house 	 c1 	 60.0
# function for setting size and/or shape 	 cc 	 100.0
# Using if-then structure to deal with alternating patterns 	 c1 	 60.0
# loops for doing repetitive tasks 	 c1 	 60.0
# nested loops (i.e. loops within loops) 	 c2 	 90.0
# Learn about Generic Game Outlines 	 cc 	 100.0
# Learn About Agents 	 cc 	 100.0
# Download the Game Library 	 cc 	 100.0
# Implement Small Board Game 	 cc 	 100.0
# Present the Logic of a Small Board Game 	 cc 	 100.0
# Learn About Search 	 cc 	 100.0
# Minimax SRPS 	 c2, p1 	 75.0
# Minimax SRPS-2 	 c2 	 90.0
# Apply Minimax to Endgame 	 00 	 0.0
# Solve the 3x3, 4x4, ... , 8x8 Queen's Problem 	 cc 	 100.0
# Write a *recipe* (on paper, or typed out) for the computer to solve the 100x100 Queen's problem 	 cc 	 100.0
# Find a solution to the sentence problem where the blanks are filled in with digits (which will upset the counts). Note that a “10” has a “1” and a “0”: This sentence contains ___ 0’s, ___ 1’s, ___ 2’s, ___ 3’s, ___ 4’s, ___ 5’s, ___ 6’s, ___ 7’s, ___ 8’s, and ___ 9’s. 	 c0 	 30.0
#
# Sprint #1 Average: 72.62
#
# Make sure that minimax works for your game 	 c1 	 60.0
# Determine how minimax scales with search size 	 nan 	 0.0
# Learn Simple Skittles Reinforcement Learning 	 c2 	 90.0
# Learn Q-Learning 	 nan 	 0.0
# Implement Skittles Agent for your game 	 nan 	 0.0
# Implement Q-learning for your game 	 nan 	 0.0
# Set Up Robot Simulator 	 nan 	 0.0
# Make python functions for simple motor tasks (e.g. moving forward a given distance, turning right 90 degrees, etc...) 	 nan 	 0.0
# Learn to have the robot take pictures and convey the images to your notebook 	 nan 	 0.0
# Look through all of the example robot scripts and summarize what they do 	 nan 	 0.0
# Make your robot do something interesting 	 nan 	 0.0
#
# Sprint #2 Average: 13.64
#
#
# Average:  52.34375
